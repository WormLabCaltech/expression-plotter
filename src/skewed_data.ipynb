# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

def randn_skew_fast(N, alpha=0.0, loc=0.0, scale=1.0):
    sigma = alpha / np.sqrt(1.0 + alpha**2) 
    u0 = np.random.randn(N)
    v = np.random.randn(N)
    u1 = (sigma*u0 + np.sqrt(1.0 - sigma**2)*v) * scale
    u1[u0 < 0] *= -1
    u1 = u1 + loc
    return u1

# %%
samples = randn_skew_fast(100000, alpha=50, scale=100, loc=50)
samples.mean()
# Out:
# 129.49359560648989

# %%
sns.distplot(samples)

# %%
samples = np.random.normal(0, 100, size=100000)
sns.distplot(samples)
